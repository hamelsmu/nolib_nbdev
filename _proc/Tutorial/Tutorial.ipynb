# %% [raw]
# ---
# description: A nbdev notebook without an associated library
# output-file: tutorial.html
# title: Tutorial
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# You can use nbdev to render docs without creating a library if you like.

# %% [markdown]
# ## Using `show_doc`
#
# [`nbdev.showdoc.show_doc`](https://nbdev.fast.ai/api/showdoc.html#show_doc) offers a nice way to render documentation for APIs:

# %% [markdown]
# Here is L from fastcore

# %%
#|output: asis
#| echo: false
show_doc(L)
# Out:
# ---
#
# [source](https://github.com/fastai/fastcore/blob/master/fastcore/foundation.py#LNone){target="_blank" style="float:right; font-size:smaller"}
#
# ### L
#
# >      L (items=None, *rest, use_list=False, match=None)
#
# Behaves like a list of `items` but can also index with list of indices or masks

# %% [markdown]
# ## Auto-linking with Backticks
#
# One cool thing about documentation functionality is the ability to link to other nbdev built projects with backtick notation.  For example the following text will be automatically turned into a link: [`fastcore.foundation.L.cycle`](https://fastcore.fast.ai/foundation.html#l.cycle):
#
# Noticed how `L.cycle` is automatically linked to the correct documentation in the sentence above!

# %% [markdown]
# ## Nbdev Directives

# %% [markdown]
# You can use nbdev directives as well.  For example you will not see the below code block, because it uses the `#|hide` directive:

# %% [markdown]
# ## Unit Tests
#
# You can still leverage the unit testing framework of nbdev with `nbdev_test` even if you have no library!

# %%
assert 'foo' != 'bar'

# %%
# !nbdev_test
# Out:
# Success.
